# %%
def sum1(n):
    final_sum = 0
    
    for x in range(n+1):
        final_sum += x
    
    return final_sum

# %%
sum1(10)
# Out:
# 55

# %%
def sum2(n):
    
    return (n*(n+1)/2)

# %%
sum2(10)
# Out:
# 55

# %%
# %timeit sum1(1000)
# Out:
# 10000 loops, best of 3: 48.4 µs per loop

# %%
# %timeit sum2(1000)
# Out:
# The slowest run took 40.55 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000000 loops, best of 3: 223 ns per loop

# %% [markdown]
# Time is not an objective metric

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0.1,100,101)

# %%
def xlogx(x):
    return x*np.log10(x)

# %%
xlogx(x)
# Out:
# array([ -1.00000000e-01,   4.50564640e-02,   6.75147905e-01,
#          1.52044491e+00,   2.50822635e+00,   3.60289964e+00,
#          4.78319553e+00,   6.03493691e+00,   7.34798813e+00,
#          8.71473858e+00,   1.01292619e+01,   1.15868116e+01,
#          1.30835006e+01,   1.46160864e+01,   1.61818233e+01,
#          1.77783561e+01,   1.94036421e+01,   2.10558932e+01,
#          2.27335306e+01,   2.44351502e+01,   2.61594953e+01,
#          2.79054342e+01,   2.96719429e+01,   3.14580899e+01,
#          3.32630244e+01,   3.50859666e+01,   3.69261986e+01,
#          3.87830575e+01,   4.06559296e+01,   4.25442448e+01,
#          4.44474722e+01,   4.63651161e+01,   4.82967129e+01,
#          5.02418277e+01,   5.22000520e+01,   5.41710013e+01,
#          5.61543129e+01,   5.81496443e+01,   6.01566715e+01,
#          6.21750873e+01,   6.42046005e+01,   6.62449342e+01,
#          6.82958251e+01,   7.03570225e+01,   7.24282871e+01,
# ...

# %%
from math import log
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
#plt.style.use('bmh')

# Set up runtime comparisons
n = np.linspace(1,10,1000)
labels = ['Constant','Logarithmic','Linear','Log Linear','Quadratic','Cubic','Exponential']
big_o = [np.ones(n.shape),np.log(n),n,n*np.log(n),n**2,n**3,2**n]

# Plot setup
plt.figure(figsize=(12,10))
plt.ylim(0,50)

for i in range(len(big_o)):
    plt.plot(n,big_o[i],label = labels[i])

plt.xlim(1,2)
plt.legend(loc=0)
plt.ylabel('Relative Runtime')
plt.xlabel('n')

# %%
# Plot setup
plt.figure(figsize=(12,10))
plt.ylim(0,50)

for i in range(len(big_o)):
    plt.plot(n,big_o[i],label = labels[i])

plt.xlim(5,6)
plt.legend(loc=0)
plt.ylabel('Relative Runtime')
plt.xlabel('n')

# %%
# Set up runtime comparisons
n = np.linspace(1,1000,1000)
labels = ['e']#['Constant','Logarithmic','Linear','Log Linear','Quadratic','Cubic','Exponential']
big_o = [np.power(1+(1/n),n)]#[np.ones(n.shape),np.log(n),n,n*np.log(n),n**2,n**3,2**n]

# Plot setup
plt.figure(figsize=(12,10))
plt.ylim(0,50)

for i in range(len(big_o)):
    plt.plot(n,big_o[i],label = labels[i])

plt.ylim(2,3)
plt.legend(loc=0)
plt.ylabel('Relative Runtime')
plt.xlabel('n')
